# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("Full_new-Table 1.csv")

# %%
df.head()
# Out:
#    Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  Height(Cm)   \
# 0       1                 1           0          28         44.6        152.0
# 1       2                 2           0          36         65.0        161.5
# 2       3                 3           1          33         68.8        165.0
# 3       4                 4           0          37         65.0        148.0
# 4       5                 5           0          25         52.0        161.0
#
#          BMI  Blood Group  Pulse rate(bpm)   RR (breaths/min)  ...  \
# 0  19.300000           15                78                22  ...
# 1  24.921163           15                74                20  ...
# 2  25.270891           11                72                18  ...
# 3  29.674945           13                72                20  ...
# 4  20.060954           11                72                18  ...
#
#    Fast food (Y/N)  Reg.Exercise(Y/N)  BP _Systolic (mmHg)  \
# ...

# %%
df.describe()
# Out:
#            Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  Weight (Kg)  \
# count  541.000000        541.000000  541.000000  541.000000   541.000000
# mean   271.000000        271.000000    0.327172   31.430684    59.637153
# std    156.317519        156.317519    0.469615    5.411006    11.028287
# min      1.000000          1.000000    0.000000   20.000000    31.000000
# 25%    136.000000        136.000000    0.000000   28.000000    52.000000
# 50%    271.000000        271.000000    0.000000   31.000000    59.000000
# 75%    406.000000        406.000000    1.000000   35.000000    65.000000
# max    541.000000        541.000000    1.000000   48.000000   108.000000
#
#        Height(Cm)          BMI  Blood Group  Pulse rate(bpm)   \
# count   541.000000  541.000000   541.000000        541.000000
# mean    156.484835   24.311285    13.802218         73.247689
# std       6.033545    4.056399     1.840812          4.430285
# ...

# %%
pd.isnull(df).sum()
# Out:
# Sl. No                      0
# Patient File No.            0
# PCOS (Y/N)                  0
#  Age (yrs)                  0
# Weight (Kg)                 0
# Height(Cm)                  0
# BMI                         0
# Blood Group                 0
# Pulse rate(bpm)             0
# RR (breaths/min)            0
# Hb(g/dl)                    0
# Cycle(R/I)                  0
# Cycle length(days)          0
# Marraige Status (Yrs)       1
# Pregnant(Y/N)               0
# No. of aborptions           0
#   I   beta-HCG(mIU/mL)      0
# II    beta-HCG(mIU/mL)      0
# FSH(mIU/mL)                 0
# LH(mIU/mL)                  0
# FSH/LH                      0
# Hip(inch)                   0
# Waist(inch)                 0
# Waist:Hip Ratio             0
# TSH (mIU/L)                 0
# AMH(ng/mL)                  0
# PRL(ng/mL)                  0
# Vit D3 (ng/mL)              0
# PRG(ng/mL)                  0
# RBS(mg/dl)                  0
# Weight gain(Y/N)            0
# ...

# %%
df= df.drop(["Unnamed: 44"], axis=1)

# %%
df.isnull().sum()
# Out:
# Sl. No                    0
# Patient File No.          0
# PCOS (Y/N)                0
#  Age (yrs)                0
# Weight (Kg)               0
# Height(Cm)                0
# BMI                       0
# Blood Group               0
# Pulse rate(bpm)           0
# RR (breaths/min)          0
# Hb(g/dl)                  0
# Cycle(R/I)                0
# Cycle length(days)        0
# Marraige Status (Yrs)     1
# Pregnant(Y/N)             0
# No. of aborptions         0
#   I   beta-HCG(mIU/mL)    0
# II    beta-HCG(mIU/mL)    0
# FSH(mIU/mL)               0
# LH(mIU/mL)                0
# FSH/LH                    0
# Hip(inch)                 0
# Waist(inch)               0
# Waist:Hip Ratio           0
# TSH (mIU/L)               0
# AMH(ng/mL)                0
# PRL(ng/mL)                0
# Vit D3 (ng/mL)            0
# PRG(ng/mL)                0
# RBS(mg/dl)                0
# Weight gain(Y/N)          0
# hair growth(Y/N)          0
# Skin darkening (Y/N)      0
# ...

# %%
df['Marraige Status (Yrs)'].fillna(0,inplace = True)
df['Fast food (Y/N)'].fillna(0,inplace = True)

# %%
df.corr()
# Out:
#                           Sl. No  Patient File No.  PCOS (Y/N)   Age (yrs)  \
# Sl. No                  1.000000          1.000000    0.060998    0.067133
# Patient File No.        1.000000          1.000000    0.060998    0.067133
# PCOS (Y/N)              0.060998          0.060998    1.000000   -0.168513
#  Age (yrs)              0.067133          0.067133   -0.168513    1.000000
# Weight (Kg)            -0.082823         -0.082823    0.211938   -0.029734
# Height(Cm)             -0.011700         -0.011700    0.068254   -0.119819
# BMI                    -0.083578         -0.083578    0.199534    0.021261
# Blood Group             0.001705          0.001705    0.036433   -0.010954
# Pulse rate(bpm)        -0.044533         -0.044533    0.091821    0.045831
# RR (breaths/min)       -0.015196         -0.015196    0.036928    0.087382
# Hb(g/dl)               -0.088681         -0.088681    0.087170   -0.021558
# ...

# %%
sns.heatmap(df.corr('pearson'), annot =True )
# Out:
# <AxesSubplot:>

# %%
df['PCOS (Y/N)'].value_counts()
# Out:
# 0    364
# 1    177
# Name: PCOS (Y/N), dtype: int64

# %%
df = df[['PCOS (Y/N)','Follicle No. (R)','Follicle No. (L)','Weight gain(Y/N)','hair growth(Y/N)','Skin darkening (Y/N)','Cycle(R/I)','Fast food (Y/N)','Cycle length(days)',' Age (yrs)']]

# %%
df['PCOS (Y/N)'].value_counts()
# Out:
# 0    364
# 1    177
# Name: PCOS (Y/N), dtype: int64

# %%
X=df.drop(["PCOS (Y/N)"],axis = 1)
y=df["PCOS (Y/N)"]

# %%
from imblearn.over_sampling import RandomOverSampler
randomoversample = RandomOverSampler(random_state=888)
X_resampled, y_resampled = randomoversample.fit_resample(X,y)
y_resampled.value_counts()
# Out:
# 0    364
# 1    364
# Name: PCOS (Y/N), dtype: int64

# %%
y_resampled
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 723    1
# 724    1
# 725    1
# 726    1
# 727    1
# Name: PCOS (Y/N), Length: 728, dtype: int64

# %%
X_resampled
# Out:
#      Follicle No. (R)  Follicle No. (L)  Weight gain(Y/N)  hair growth(Y/N)  \
# 0                   3                 3                 0                 0
# 1                   5                 3                 0                 0
# 2                  15                13                 0                 0
# 3                   2                 2                 0                 0
# 4                   4                 3                 0                 0
# ..                ...               ...               ...               ...
# 723                 6                 4                 1                 0
# 724                 2                 4                 1                 1
# 725                 7                10                 1                 1
# 726                12                 4                 1                 1
# 727                10                11                 1                 1
#
# ...

# %%
df.dtypes
# Out:
# PCOS (Y/N)                int64
# Follicle No. (R)          int64
# Follicle No. (L)          int64
# Weight gain(Y/N)          int64
# hair growth(Y/N)          int64
# Skin darkening (Y/N)      int64
# Cycle(R/I)                int64
# Fast food (Y/N)         float64
# Cycle length(days)        int64
#  Age (yrs)                int64
# dtype: object

# %%
df['PCOS (Y/N)'].value_counts()
# Out:
# 0    364
# 1    177
# Name: PCOS (Y/N), dtype: int64

# %%
X_resampled.dtypes
# Out:
# Follicle No. (R)          int64
# Follicle No. (L)          int64
# Weight gain(Y/N)          int64
# hair growth(Y/N)          int64
# Skin darkening (Y/N)      int64
# Cycle(R/I)                int64
# Fast food (Y/N)         float64
# Cycle length(days)        int64
#  Age (yrs)                int64
# dtype: object

# %%
X_resampled
# Out:
#      Follicle No. (R)  Follicle No. (L)  Weight gain(Y/N)  hair growth(Y/N)  \
# 0                   3                 3                 0                 0
# 1                   5                 3                 0                 0
# 2                  15                13                 0                 0
# 3                   2                 2                 0                 0
# 4                   4                 3                 0                 0
# ..                ...               ...               ...               ...
# 723                 6                 4                 1                 0
# 724                 2                 4                 1                 1
# 725                 7                10                 1                 1
# 726                12                 4                 1                 1
# 727                10                11                 1                 1
#
# ...

# %%
X_resampled["PCOS"]= y_resampled

# %%
X_resampled
# Out:
#      Follicle No. (R)  Follicle No. (L)  Weight gain(Y/N)  hair growth(Y/N)  \
# 0                   3                 3                 0                 0
# 1                   5                 3                 0                 0
# 2                  15                13                 0                 0
# 3                   2                 2                 0                 0
# 4                   4                 3                 0                 0
# ..                ...               ...               ...               ...
# 723                 6                 4                 1                 0
# 724                 2                 4                 1                 1
# 725                 7                10                 1                 1
# 726                12                 4                 1                 1
# 727                10                11                 1                 1
#
# ...

# %%
X_resampled['PCOS'].value_counts()
# Out:
# 0    364
# 1    364
# Name: PCOS, dtype: int64

# %%
testmodify= X_resampled.insert(0, 'New_ID', range(0, 0 + len(X_resampled)))

# %%
X_resampled
# Out:
#      New_ID  Follicle No. (R)  Follicle No. (L)  Weight gain(Y/N)  \
# 0         0                 3                 3                 0
# 1         1                 5                 3                 0
# 2         2                15                13                 0
# 3         3                 2                 2                 0
# 4         4                 4                 3                 0
# ..      ...               ...               ...               ...
# 723     723                 6                 4                 1
# 724     724                 2                 4                 1
# 725     725                 7                10                 1
# 726     726                12                 4                 1
# 727     727                10                11                 1
#
#      hair growth(Y/N)  Skin darkening (Y/N)  Cycle(R/I)  Fast food (Y/N)  \
# 0                   0                     0           2              1.0
# ...

# %%
compression_opts = dict(method='zip',
                        archive_name='out.csv')
X_resampled.to_csv('out.zip', index=False,
          compression=compression_opts)

# %%
X_resampled.to_csv('out.csv')

# %%
training= X_resampled[X_resampled["New_ID"]<510]
validate= X_resampled[X_resampled["New_ID"]>509]

# %%
training
validate
# Out:
#      New_ID  Follicle No. (R)  Follicle No. (L)  Weight gain(Y/N)  \
# 510     510                10                 8                 1
# 511     511                 5                 9                 0
# 512     512                10                 8                 0
# 513     513                 3                 1                 0
# 514     514                 7                 9                 0
# ..      ...               ...               ...               ...
# 723     723                 6                 4                 1
# 724     724                 2                 4                 1
# 725     725                 7                10                 1
# 726     726                12                 4                 1
# 727     727                10                11                 1
#
#      hair growth(Y/N)  Skin darkening (Y/N)  Cycle(R/I)  Fast food (Y/N)  \
# 510                 0                     0           2              0.0
# ...

# %%
training.to_csv('pcostrain.csv')

# %%
validate.to_csv('pcosvalidate.csv')

# %%
#dropping age and cycle length
training2=training[['Follicle No. (R)','Follicle No. (L)','Weight gain(Y/N)','hair growth(Y/N)','Skin darkening (Y/N)','Cycle(R/I)','Fast food (Y/N)','PCOS']]

validate2=validate[['Follicle No. (R)','Follicle No. (L)','Weight gain(Y/N)','hair growth(Y/N)','Skin darkening (Y/N)','Cycle(R/I)','Fast food (Y/N)','PCOS']]

# %%
training2.to_csv('pcostrain2.csv')
validate2.to_csv('pcosvalidate2.csv')
